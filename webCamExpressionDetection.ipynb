# %%
import pandas as pd
import cv2
import numpy as np

# %%
dataset_path = 'fer2013/fer2013.csv'
image_size=(48,48)

# %%
def load_fer2013():
    data = pd.read_csv(dataset_path)
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = pd.get_dummies(data['emotion']).values
    return faces, emotions

# %%
def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
        
    return x

# %%
from sklearn.model_selection import train_test_split
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)

# %%
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras.layers import Activation, Convolution2D, Dropout, Conv2D
from keras.layers import AveragePooling2D, BatchNormalization
from keras.layers import GlobalAveragePooling2D
from keras.models import Sequential
from keras.layers import Flatten
from keras.models import Model
from keras.layers import Input
from keras.layers import MaxPooling2D
from keras.layers import SeparableConv2D
from keras import layers
from keras.regularizers import l2
import pandas as pd
import cv2
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# parameters
batch_size = 32
num_epochs = 110
input_shape = (48, 48, 1)
verbose = 1
num_classes = 7
patience = 50
base_path = 'models/'
l2_regularization=0.01

# %%
# data generator
data_generator = ImageDataGenerator(
                        featurewise_center=False,
                        featurewise_std_normalization=False,
                        rotation_range=10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)

# %%
# model parameters
regularization = l2(l2_regularization)

# %%
# base
img_input = Input(input_shape)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Conv2D(8, (3, 3), strides=(1, 1), kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# %%
# module 1
residual = Conv2D(16, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(16, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])

# %%
# module 2
residual = Conv2D(32, (1, 1), strides=(2, 2), padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(32, (3, 3), padding='same', kernel_regularizer=regularization, use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])

# %%
# module 3
residual = Conv2D(64, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(64, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])

# %%
# module 4
residual = Conv2D(128, (1, 1), strides=(2, 2),padding='same', use_bias=False)(x)
residual = BatchNormalization()(residual)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = SeparableConv2D(128, (3, 3), padding='same',kernel_regularizer=regularization,use_bias=False)(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = layers.add([x, residual])
x = Conv2D(num_classes, (3, 3), padding='same')(x)
x = GlobalAveragePooling2D()(x)
output = Activation('softmax',name='predictions')(x)

# %%
model = Model(img_input, output)
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 48, 48, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 46, 46, 8)    72          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 46, 46, 8)    32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 46, 46, 8)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 44, 44, 8)    576         activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 44, 44, 8)    32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 44, 44, 8)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 44, 44, 16)   200         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 44, 44, 16)   64          separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 44, 44, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 44, 44, 16)   400         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 44, 44, 16)   64          separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 22, 22, 16)   128         activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 22, 22, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 22, 22, 16)   64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 22, 22, 16)   0           max_pooling2d_1[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 22, 22, 32)   656         add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 22, 22, 32)   128         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 22, 22, 32)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 22, 22, 32)   1312        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 22, 22, 32)   128         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 11, 11, 32)   512         add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 11, 11, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 11, 11, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 11, 11, 32)   0           max_pooling2d_2[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 11, 11, 64)   2336        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 11, 11, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 11, 11, 64)   4672        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 11, 11, 64)   256         separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 6, 6, 64)     2048        add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 64)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 6, 6, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 6, 6, 64)     0           max_pooling2d_3[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 6, 6, 128)    8768        add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 6, 6, 128)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 6, 6, 128)    17536       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 6, 6, 128)    512         separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 3, 3, 128)    8192        add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 3, 3, 128)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 3, 3, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 3, 3, 128)    0           max_pooling2d_4[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 3, 3, 7)      8071        add_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 7)            0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# predictions (Activation)        (None, 7)            0           global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 58,423
# Trainable params: 56,951
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
# callbacks
log_file_path = base_path + '_emotion_training.log'
csv_logger = CSVLogger(log_file_path, append=False)
early_stop = EarlyStopping('val_loss', patience=patience)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.1, patience=int(patience/4), verbose=1)
trained_models_path = base_path + '_mini_XCEPTION'
model_names = trained_models_path + '.{epoch:02d}.hdf5'#-{val_acc:.2f}
model_checkpoint = ModelCheckpoint(model_names, 'val_loss', verbose=1,save_best_only=True)
callbacks = [model_checkpoint, csv_logger, early_stop, reduce_lr]
 
model.fit_generator(data_generator.flow(xtrain, ytrain,batch_size),
                    steps_per_epoch=len(xtrain) / batch_size,
                    epochs=num_epochs, verbose=1, callbacks=callbacks,
                    validation_data=(xtest,ytest))
# Out:
# Epoch 1/110
# 898/897 [==============================] - 268s 298ms/step - loss: 1.7474 - accuracy: 0.3413 - val_loss: 1.5612 - val_accuracy: 0.4312
#
# Epoch 00001: val_loss improved from inf to 1.56122, saving model to models/_mini_XCEPTION.01.hdf5
# Epoch 2/110
# 898/897 [==============================] - 233s 260ms/step - loss: 1.4847 - accuracy: 0.4471 - val_loss: 1.5512 - val_accuracy: 0.4351
#
# Epoch 00002: val_loss improved from 1.56122 to 1.55117, saving model to models/_mini_XCEPTION.02.hdf5
# Epoch 3/110
# 898/897 [==============================] - 218s 243ms/step - loss: 1.3726 - accuracy: 0.4870 - val_loss: 1.5393 - val_accuracy: 0.4380
#
# Epoch 00003: val_loss improved from 1.55117 to 1.53928, saving model to models/_mini_XCEPTION.03.hdf5
# Epoch 4/110
# 898/897 [==============================] - 240s 267ms/step - loss: 1.3053 - accuracy: 0.5117 - val_loss: 1.4574 - val_accuracy: 0.4600
#
# Epoch 00004: val_loss improved from 1.53928 to 1.45737, saving model to models/_mini_XCEPTION.04.hdf5
# Epoch 5/110
# 898/897 [==============================] - 245s 273ms/step - loss: 1.2686 - accuracy: 0.5268 - val_loss: 1.1931 - val_accuracy: 0.5531
#
# Epoch 00005: val_loss improved from 1.45737 to 1.19312, saving model to models/_mini_XCEPTION.05.hdf5
# Epoch 6/110
# 898/897 [==============================] - 265s 295ms/step - loss: 1.2241 - accuracy: 0.5428 - val_loss: 1.2420 - val_accuracy: 0.5411
#
# Epoch 00006: val_loss did not improve from 1.19312
# Epoch 7/110
# 898/897 [==============================] - 253s 282ms/step - loss: 1.2023 - accuracy: 0.5521 - val_loss: 1.1635 - val_accuracy: 0.5606
#
# Epoch 00007: val_loss improved from 1.19312 to 1.16352, saving model to models/_mini_XCEPTION.07.hdf5
# Epoch 8/110
# 898/897 [==============================] - 306s 341ms/step - loss: 1.1793 - accuracy: 0.5585 - val_loss: 1.1652 - val_accuracy: 0.5632
#
# Epoch 00008: val_loss did not improve from 1.16352
# Epoch 9/110
# 898/897 [==============================] - 308s 343ms/step - loss: 1.1588 - accuracy: 0.5663 - val_loss: 1.2304 - val_accuracy: 0.5609
#
# Epoch 00009: val_loss did not improve from 1.16352
# Epoch 10/110
# 898/897 [==============================] - 316s 352ms/step - loss: 1.1486 - accuracy: 0.5732 - val_loss: 1.1870 - val_accuracy: 0.5667
#
# Epoch 00010: val_loss did not improve from 1.16352
# Epoch 11/110
# 898/897 [==============================] - 332s 369ms/step - loss: 1.1353 - accuracy: 0.5721 - val_loss: 1.1544 - val_accuracy: 0.5673
#
# Epoch 00011: val_loss improved from 1.16352 to 1.15439, saving model to models/_mini_XCEPTION.11.hdf5
# Epoch 12/110
# 898/897 [==============================] - 339s 378ms/step - loss: 1.1199 - accuracy: 0.5841 - val_loss: 1.1323 - val_accuracy: 0.5769
#
# Epoch 00012: val_loss improved from 1.15439 to 1.13228, saving model to models/_mini_XCEPTION.12.hdf5
# Epoch 13/110
# 898/897 [==============================] - 308s 344ms/step - loss: 1.1131 - accuracy: 0.5828 - val_loss: 1.1871 - val_accuracy: 0.5581
#
# Epoch 00013: val_loss did not improve from 1.13228
# Epoch 14/110
# 898/897 [==============================] - 295s 328ms/step - loss: 1.1025 - accuracy: 0.5887 - val_loss: 1.1549 - val_accuracy: 0.5674
#
# Epoch 00014: val_loss did not improve from 1.13228
# Epoch 15/110
# 898/897 [==============================] - 318s 354ms/step - loss: 1.0900 - accuracy: 0.5921 - val_loss: 1.1492 - val_accuracy: 0.5715
#
# Epoch 00015: val_loss did not improve from 1.13228
# Epoch 16/110
# 898/897 [==============================] - 291s 324ms/step - loss: 1.0842 - accuracy: 0.5988 - val_loss: 1.1628 - val_accuracy: 0.5634
#
# Epoch 00016: val_loss did not improve from 1.13228
# Epoch 17/110
# 898/897 [==============================] - 315s 351ms/step - loss: 1.0729 - accuracy: 0.5991 - val_loss: 1.0951 - val_accuracy: 0.5907
#
# Epoch 00017: val_loss improved from 1.13228 to 1.09506, saving model to models/_mini_XCEPTION.17.hdf5
# Epoch 18/110
# 898/897 [==============================] - 329s 366ms/step - loss: 1.0654 - accuracy: 0.6013 - val_loss: 1.1057 - val_accuracy: 0.5924
#
# Epoch 00018: val_loss did not improve from 1.09506
# Epoch 19/110
# 898/897 [==============================] - 236s 263ms/step - loss: 1.0584 - accuracy: 0.6052 - val_loss: 1.0897 - val_accuracy: 0.5939
#
# Epoch 00019: val_loss improved from 1.09506 to 1.08969, saving model to models/_mini_XCEPTION.19.hdf5
# Epoch 20/110
# 898/897 [==============================] - 259s 288ms/step - loss: 1.0539 - accuracy: 0.6064 - val_loss: 1.0679 - val_accuracy: 0.6006
#
# Epoch 00020: val_loss improved from 1.08969 to 1.06787, saving model to models/_mini_XCEPTION.20.hdf5
# Epoch 21/110
# 898/897 [==============================] - 292s 325ms/step - loss: 1.0464 - accuracy: 0.6106 - val_loss: 1.0748 - val_accuracy: 0.5922
#
# Epoch 00021: val_loss did not improve from 1.06787
# Epoch 22/110
# 898/897 [==============================] - 268s 298ms/step - loss: 1.0404 - accuracy: 0.6127 - val_loss: 1.2301 - val_accuracy: 0.5300
#
# Epoch 00022: val_loss did not improve from 1.06787
# Epoch 23/110
# 898/897 [==============================] - 268s 299ms/step - loss: 1.0394 - accuracy: 0.6108 - val_loss: 1.1734 - val_accuracy: 0.5645
#
# Epoch 00023: val_loss did not improve from 1.06787
# Epoch 24/110
# 898/897 [==============================] - 290s 323ms/step - loss: 1.0378 - accuracy: 0.6096 - val_loss: 1.0750 - val_accuracy: 0.5926
#
# Epoch 00024: val_loss did not improve from 1.06787
# Epoch 25/110
# 898/897 [==============================] - 315s 351ms/step - loss: 1.0305 - accuracy: 0.6153 - val_loss: 1.0982 - val_accuracy: 0.5970
#
# Epoch 00025: val_loss did not improve from 1.06787
# Epoch 26/110
# 898/897 [==============================] - 328s 365ms/step - loss: 1.0215 - accuracy: 0.6174 - val_loss: 1.0667 - val_accuracy: 0.6013
#
# Epoch 00026: val_loss improved from 1.06787 to 1.06670, saving model to models/_mini_XCEPTION.26.hdf5
# Epoch 27/110
# 898/897 [==============================] - 311s 346ms/step - loss: 1.0193 - accuracy: 0.6217 - val_loss: 1.1140 - val_accuracy: 0.5883
#
# Epoch 00027: val_loss did not improve from 1.06670
# Epoch 28/110
# 898/897 [==============================] - 290s 323ms/step - loss: 1.0121 - accuracy: 0.6240 - val_loss: 1.0964 - val_accuracy: 0.5867
#
# Epoch 00028: val_loss did not improve from 1.06670
# Epoch 29/110
# 898/897 [==============================] - 283s 315ms/step - loss: 1.0097 - accuracy: 0.6237 - val_loss: 1.0753 - val_accuracy: 0.6004
#
# Epoch 00029: val_loss did not improve from 1.06670
# Epoch 30/110
# 898/897 [==============================] - 266s 296ms/step - loss: 1.0122 - accuracy: 0.6200 - val_loss: 1.0772 - val_accuracy: 0.5926
#
# Epoch 00030: val_loss did not improve from 1.06670
# Epoch 31/110
# 898/897 [==============================] - 238s 265ms/step - loss: 1.0056 - accuracy: 0.6258 - val_loss: 1.1127 - val_accuracy: 0.5929
#
# Epoch 00031: val_loss did not improve from 1.06670
# Epoch 32/110
# 898/897 [==============================] - 232s 258ms/step - loss: 0.9969 - accuracy: 0.6300 - val_loss: 1.1734 - val_accuracy: 0.5711
#
# Epoch 00032: val_loss did not improve from 1.06670
# Epoch 33/110
# 898/897 [==============================] - 235s 261ms/step - loss: 0.9982 - accuracy: 0.6282 - val_loss: 1.0414 - val_accuracy: 0.6166
#
# Epoch 00033: val_loss improved from 1.06670 to 1.04143, saving model to models/_mini_XCEPTION.33.hdf5
# Epoch 34/110
# 898/897 [==============================] - 230s 256ms/step - loss: 0.9931 - accuracy: 0.6316 - val_loss: 1.0432 - val_accuracy: 0.6105
#
# Epoch 00034: val_loss did not improve from 1.04143
# Epoch 35/110
# 898/897 [==============================] - 237s 264ms/step - loss: 0.9870 - accuracy: 0.6334 - val_loss: 1.0413 - val_accuracy: 0.6179
#
# Epoch 00035: val_loss improved from 1.04143 to 1.04126, saving model to models/_mini_XCEPTION.35.hdf5
# Epoch 36/110
# 898/897 [==============================] - 215s 240ms/step - loss: 0.9909 - accuracy: 0.6311 - val_loss: 1.0829 - val_accuracy: 0.6049
#
# Epoch 00036: val_loss did not improve from 1.04126
# Epoch 37/110
# 898/897 [==============================] - 213s 237ms/step - loss: 0.9843 - accuracy: 0.6323 - val_loss: 1.0253 - val_accuracy: 0.6176
#
# Epoch 00037: val_loss improved from 1.04126 to 1.02532, saving model to models/_mini_XCEPTION.37.hdf5
# Epoch 38/110
# 898/897 [==============================] - 206s 230ms/step - loss: 0.9821 - accuracy: 0.6340 - val_loss: 1.0808 - val_accuracy: 0.6010
#
# Epoch 00038: val_loss did not improve from 1.02532
# Epoch 39/110
# 898/897 [==============================] - 211s 235ms/step - loss: 0.9774 - accuracy: 0.6340 - val_loss: 1.0056 - val_accuracy: 0.6265
#
# Epoch 00039: val_loss improved from 1.02532 to 1.00557, saving model to models/_mini_XCEPTION.39.hdf5
# Epoch 40/110
# 898/897 [==============================] - 248s 277ms/step - loss: 0.9764 - accuracy: 0.6329 - val_loss: 1.0421 - val_accuracy: 0.6123
#
# Epoch 00040: val_loss did not improve from 1.00557
# Epoch 41/110
# 898/897 [==============================] - 222s 247ms/step - loss: 0.9715 - accuracy: 0.6405 - val_loss: 1.0788 - val_accuracy: 0.6076
#
# Epoch 00041: val_loss did not improve from 1.00557
# Epoch 42/110
# 898/897 [==============================] - 225s 251ms/step - loss: 0.9653 - accuracy: 0.6402 - val_loss: 1.0744 - val_accuracy: 0.6102
#
# Epoch 00042: val_loss did not improve from 1.00557
# Epoch 43/110
# 898/897 [==============================] - 234s 261ms/step - loss: 0.9643 - accuracy: 0.6405 - val_loss: 1.0423 - val_accuracy: 0.6195
#
# Epoch 00043: val_loss did not improve from 1.00557
# Epoch 44/110
# 898/897 [==============================] - 225s 251ms/step - loss: 0.9645 - accuracy: 0.6421 - val_loss: 1.0750 - val_accuracy: 0.6034
#
# Epoch 00044: val_loss did not improve from 1.00557
# Epoch 45/110
# 898/897 [==============================] - 222s 247ms/step - loss: 0.9583 - accuracy: 0.6428 - val_loss: 1.0762 - val_accuracy: 0.6014
#
# Epoch 00045: val_loss did not improve from 1.00557
# Epoch 46/110
# 898/897 [==============================] - 231s 258ms/step - loss: 0.9641 - accuracy: 0.6399 - val_loss: 1.0155 - val_accuracy: 0.6236
#
# Epoch 00046: val_loss did not improve from 1.00557
# Epoch 47/110
# 898/897 [==============================] - 214s 238ms/step - loss: 0.9591 - accuracy: 0.6443 - val_loss: 1.1202 - val_accuracy: 0.5957
#
# Epoch 00047: val_loss did not improve from 1.00557
# Epoch 48/110
# 898/897 [==============================] - 209s 232ms/step - loss: 0.9581 - accuracy: 0.6420 - val_loss: 1.0389 - val_accuracy: 0.6218
#
# Epoch 00048: val_loss did not improve from 1.00557
# Epoch 49/110
# 898/897 [==============================] - 208s 231ms/step - loss: 0.9493 - accuracy: 0.6513 - val_loss: 1.0481 - val_accuracy: 0.6141
#
# Epoch 00049: val_loss did not improve from 1.00557
# Epoch 50/110
# 898/897 [==============================] - 208s 231ms/step - loss: 0.9494 - accuracy: 0.6484 - val_loss: 1.0549 - val_accuracy: 0.6142
#
# Epoch 00050: val_loss did not improve from 1.00557
# Epoch 51/110
# 898/897 [==============================] - 208s 232ms/step - loss: 0.9477 - accuracy: 0.6492 - val_loss: 1.0156 - val_accuracy: 0.6227
#
# Epoch 00051: val_loss did not improve from 1.00557
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 52/110
# 898/897 [==============================] - 208s 231ms/step - loss: 0.8990 - accuracy: 0.6697 - val_loss: 0.9857 - val_accuracy: 0.6354
#
# Epoch 00052: val_loss improved from 1.00557 to 0.98573, saving model to models/_mini_XCEPTION.52.hdf5
# Epoch 53/110
# 898/897 [==============================] - 209s 232ms/step - loss: 0.8846 - accuracy: 0.6740 - val_loss: 0.9805 - val_accuracy: 0.6407
#
# Epoch 00053: val_loss improved from 0.98573 to 0.98048, saving model to models/_mini_XCEPTION.53.hdf5
# Epoch 54/110
# 898/897 [==============================] - 209s 233ms/step - loss: 0.8755 - accuracy: 0.6783 - val_loss: 0.9813 - val_accuracy: 0.6376
#
# Epoch 00054: val_loss did not improve from 0.98048
# Epoch 55/110
# 898/897 [==============================] - 208s 231ms/step - loss: 0.8734 - accuracy: 0.6803 - val_loss: 0.9805 - val_accuracy: 0.6383
#
# Epoch 00055: val_loss improved from 0.98048 to 0.98047, saving model to models/_mini_XCEPTION.55.hdf5
# Epoch 56/110
# 898/897 [==============================] - 207s 231ms/step - loss: 0.8743 - accuracy: 0.6752 - val_loss: 0.9811 - val_accuracy: 0.6349
#
# Epoch 00056: val_loss did not improve from 0.98047
# Epoch 57/110
# 898/897 [==============================] - 210s 234ms/step - loss: 0.8713 - accuracy: 0.6790 - val_loss: 0.9788 - val_accuracy: 0.6333
#
# Epoch 00057: val_loss improved from 0.98047 to 0.97884, saving model to models/_mini_XCEPTION.57.hdf5
# Epoch 58/110
# 898/897 [==============================] - 204s 227ms/step - loss: 0.8706 - accuracy: 0.6762 - val_loss: 0.9800 - val_accuracy: 0.6365
#
# Epoch 00058: val_loss did not improve from 0.97884
# Epoch 59/110
# 898/897 [==============================] - 210s 234ms/step - loss: 0.8674 - accuracy: 0.6799 - val_loss: 0.9839 - val_accuracy: 0.6382
#
# Epoch 00059: val_loss did not improve from 0.97884
# Epoch 60/110
# 898/897 [==============================] - 209s 233ms/step - loss: 0.8671 - accuracy: 0.6822 - val_loss: 0.9807 - val_accuracy: 0.6389
#
# Epoch 00060: val_loss did not improve from 0.97884
# Epoch 61/110
# 898/897 [==============================] - 205s 228ms/step - loss: 0.8606 - accuracy: 0.6831 - val_loss: 0.9759 - val_accuracy: 0.6410
#
# Epoch 00061: val_loss improved from 0.97884 to 0.97595, saving model to models/_mini_XCEPTION.61.hdf5
# Epoch 62/110
# 898/897 [==============================] - 207s 231ms/step - loss: 0.8614 - accuracy: 0.6807 - val_loss: 0.9779 - val_accuracy: 0.6399
#
# Epoch 00062: val_loss did not improve from 0.97595
# Epoch 63/110
# 898/897 [==============================] - 209s 233ms/step - loss: 0.8548 - accuracy: 0.6827 - val_loss: 0.9780 - val_accuracy: 0.6402
#
# Epoch 00063: val_loss did not improve from 0.97595
# Epoch 64/110
# 898/897 [==============================] - 206s 230ms/step - loss: 0.8567 - accuracy: 0.6841 - val_loss: 0.9779 - val_accuracy: 0.6383
#
# Epoch 00064: val_loss did not improve from 0.97595
# Epoch 65/110
# 898/897 [==============================] - 208s 231ms/step - loss: 0.8517 - accuracy: 0.6848 - val_loss: 0.9841 - val_accuracy: 0.6344
#
# Epoch 00065: val_loss did not improve from 0.97595
# Epoch 66/110
# 898/897 [==============================] - 210s 233ms/step - loss: 0.8543 - accuracy: 0.6835 - val_loss: 0.9755 - val_accuracy: 0.6390
#
# Epoch 00066: val_loss improved from 0.97595 to 0.97554, saving model to models/_mini_XCEPTION.66.hdf5
# Epoch 67/110
# 898/897 [==============================] - 204s 227ms/step - loss: 0.8496 - accuracy: 0.6866 - val_loss: 0.9704 - val_accuracy: 0.6399
#
# Epoch 00067: val_loss improved from 0.97554 to 0.97043, saving model to models/_mini_XCEPTION.67.hdf5
# Epoch 68/110
# 898/897 [==============================] - 210s 234ms/step - loss: 0.8506 - accuracy: 0.6838 - val_loss: 0.9770 - val_accuracy: 0.6393
#
# Epoch 00068: val_loss did not improve from 0.97043
# Epoch 69/110
# 898/897 [==============================] - 205s 229ms/step - loss: 0.8551 - accuracy: 0.6829 - val_loss: 0.9761 - val_accuracy: 0.6417
#
# Epoch 00069: val_loss did not improve from 0.97043
# Epoch 70/110
# 898/897 [==============================] - 207s 231ms/step - loss: 0.8444 - accuracy: 0.6875 - val_loss: 0.9734 - val_accuracy: 0.6427
#
# Epoch 00070: val_loss did not improve from 0.97043
# Epoch 71/110
# 898/897 [==============================] - 210s 234ms/step - loss: 0.8562 - accuracy: 0.6840 - val_loss: 0.9765 - val_accuracy: 0.6411
#
# Epoch 00071: val_loss did not improve from 0.97043
# Epoch 72/110
# 898/897 [==============================] - 206s 229ms/step - loss: 0.8486 - accuracy: 0.6886 - val_loss: 0.9713 - val_accuracy: 0.6417
#
# Epoch 00072: val_loss did not improve from 0.97043
# Epoch 73/110
# 898/897 [==============================] - 207s 231ms/step - loss: 0.8522 - accuracy: 0.6848 - val_loss: 0.9744 - val_accuracy: 0.6403
#
# Epoch 00073: val_loss did not improve from 0.97043
# Epoch 74/110
# 898/897 [==============================] - 207s 231ms/step - loss: 0.8467 - accuracy: 0.6869 - val_loss: 0.9806 - val_accuracy: 0.6379
#
# Epoch 00074: val_loss did not improve from 0.97043
# Epoch 75/110
# 898/897 [==============================] - 210s 234ms/step - loss: 0.8507 - accuracy: 0.6858 - val_loss: 0.9723 - val_accuracy: 0.6424
#
# Epoch 00075: val_loss did not improve from 0.97043
# Epoch 76/110
# 898/897 [==============================] - 208s 232ms/step - loss: 0.8459 - accuracy: 0.6870 - val_loss: 0.9731 - val_accuracy: 0.6411
# Epoch 00076: val_loss did not improve from 0.97043
# Epoch 77/110
# 898/897 [==============================] - 200s 223ms/step - loss: 0.8440 - accuracy: 0.6857 - val_loss: 0.9737 - val_accuracy: 0.6408
#
# Epoch 00077: val_loss did not improve from 0.97043
# Epoch 78/110
# 898/897 [==============================] - 204s 227ms/step - loss: 0.8443 - accuracy: 0.6862 - val_loss: 0.9838 - val_accuracy: 0.6418
#
# Epoch 00078: val_loss did not improve from 0.97043
# Epoch 79/110
# 898/897 [==============================] - 202s 225ms/step - loss: 0.8425 - accuracy: 0.6893 - val_loss: 0.9887 - val_accuracy: 0.6393
#
# Epoch 00079: val_loss did not improve from 0.97043
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 80/110
# 898/897 [==============================] - 202s 225ms/step - loss: 0.8348 - accuracy: 0.6916 - val_loss: 0.9748 - val_accuracy: 0.6428
#
# Epoch 00080: val_loss did not improve from 0.97043
# Epoch 81/110
# 898/897 [==============================] - 204s 227ms/step - loss: 0.8353 - accuracy: 0.6919 - val_loss: 0.9726 - val_accuracy: 0.6425
#
# Epoch 00081: val_loss did not improve from 0.97043
# Epoch 82/110
# 898/897 [==============================] - 202s 225ms/step - loss: 0.8361 - accuracy: 0.6905 - val_loss: 0.9715 - val_accuracy: 0.6441
#
# Epoch 00082: val_loss did not improve from 0.97043
# Epoch 83/110
# 898/897 [==============================] - 201s 224ms/step - loss: 0.8362 - accuracy: 0.6910 - val_loss: 0.9705 - val_accuracy: 0.6443
#
# Epoch 00083: val_loss did not improve from 0.97043
# Epoch 84/110
# 898/897 [==============================] - 204s 227ms/step - loss: 0.8345 - accuracy: 0.6917 - val_loss: 0.9708 - val_accuracy: 0.6441
#
# Epoch 00084: val_loss did not improve from 0.97043
# Epoch 85/110
# 898/897 [==============================] - 202s 225ms/step - loss: 0.8372 - accuracy: 0.6907 - val_loss: 0.9723 - val_accuracy: 0.6429
#
# Epoch 00085: val_loss did not improve from 0.97043
# Epoch 86/110
# 898/897 [==============================] - 201s 224ms/step - loss: 0.8346 - accuracy: 0.6899 - val_loss: 0.9714 - val_accuracy: 0.6429
#
# Epoch 00086: val_loss did not improve from 0.97043
# Epoch 87/110
# 898/897 [==============================] - 209s 232ms/step - loss: 0.8293 - accuracy: 0.6932 - val_loss: 0.9726 - val_accuracy: 0.6425
#
# Epoch 00087: val_loss did not improve from 0.97043
# Epoch 88/110
# 898/897 [==============================] - 206s 229ms/step - loss: 0.8315 - accuracy: 0.6933 - val_loss: 0.9715 - val_accuracy: 0.6431
#
# Epoch 00088: val_loss did not improve from 0.97043
# Epoch 89/110
# 898/897 [==============================] - 205s 229ms/step - loss: 0.8366 - accuracy: 0.6906 - val_loss: 0.9718 - val_accuracy: 0.6425
#
# Epoch 00089: val_loss did not improve from 0.97043
# Epoch 90/110
# 898/897 [==============================] - 210s 234ms/step - loss: 0.8283 - accuracy: 0.6937 - val_loss: 0.9722 - val_accuracy: 0.6411
#
# Epoch 00090: val_loss did not improve from 0.97043
# Epoch 91/110
# 898/897 [==============================] - 210s 234ms/step - loss: 0.8316 - accuracy: 0.6930 - val_loss: 0.9728 - val_accuracy: 0.6420
#
# Epoch 00091: val_loss did not improve from 0.97043
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Epoch 92/110
# 898/897 [==============================] - 227s 253ms/step - loss: 0.8287 - accuracy: 0.6949 - val_loss: 0.9731 - val_accuracy: 0.6414
#
# Epoch 00092: val_loss did not improve from 0.97043
# Epoch 93/110
# 898/897 [==============================] - 236s 263ms/step - loss: 0.8268 - accuracy: 0.6935 - val_loss: 0.9736 - val_accuracy: 0.6411
#
# Epoch 00093: val_loss did not improve from 0.97043
# Epoch 94/110
# 898/897 [==============================] - 245s 273ms/step - loss: 0.8302 - accuracy: 0.6941 - val_loss: 0.9720 - val_accuracy: 0.6429
#
# Epoch 00094: val_loss did not improve from 0.97043
# Epoch 95/110
# 898/897 [==============================] - 228s 254ms/step - loss: 0.8268 - accuracy: 0.6968 - val_loss: 0.9716 - val_accuracy: 0.6434
#
# Epoch 00095: val_loss did not improve from 0.97043
# Epoch 96/110
# 898/897 [==============================] - 231s 257ms/step - loss: 0.8322 - accuracy: 0.6928 - val_loss: 0.9718 - val_accuracy: 0.6428
#
# Epoch 00096: val_loss did not improve from 0.97043
# Epoch 97/110
# 898/897 [==============================] - 232s 259ms/step - loss: 0.8317 - accuracy: 0.6948 - val_loss: 0.9724 - val_accuracy: 0.6420
#
# Epoch 00097: val_loss did not improve from 0.97043
# Epoch 98/110
# 898/897 [==============================] - 233s 259ms/step - loss: 0.8308 - accuracy: 0.6912 - val_loss: 0.9722 - val_accuracy: 0.6425
#
# Epoch 00098: val_loss did not improve from 0.97043
# Epoch 99/110
# 898/897 [==============================] - 228s 254ms/step - loss: 0.8261 - accuracy: 0.6942 - val_loss: 0.9717 - val_accuracy: 0.6435
#
# Epoch 00099: val_loss did not improve from 0.97043
# Epoch 100/110
# 898/897 [==============================] - 225s 250ms/step - loss: 0.8308 - accuracy: 0.6930 - val_loss: 0.9710 - val_accuracy: 0.6432
#
# Epoch 00100: val_loss did not improve from 0.97043
# Epoch 101/110
# 898/897 [==============================] - 224s 249ms/step - loss: 0.8334 - accuracy: 0.6927 - val_loss: 0.9728 - val_accuracy: 0.6421
#
# Epoch 00101: val_loss did not improve from 0.97043
# Epoch 102/110
# 898/897 [==============================] - 230s 256ms/step - loss: 0.8281 - accuracy: 0.6961 - val_loss: 0.9727 - val_accuracy: 0.6432
#
# Epoch 00102: val_loss did not improve from 0.97043
# Epoch 103/110
# 898/897 [==============================] - 204s 227ms/step - loss: 0.8336 - accuracy: 0.6928 - val_loss: 0.9719 - val_accuracy: 0.6434
#
# Epoch 00103: val_loss did not improve from 0.97043
#
# Epoch 00103: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# Epoch 104/110
# 898/897 [==============================] - 218s 242ms/step - loss: 0.8317 - accuracy: 0.6926 - val_loss: 0.9720 - val_accuracy: 0.6422
#
# Epoch 00104: val_loss did not improve from 0.97043
# Epoch 105/110
# 898/897 [==============================] - 223s 248ms/step - loss: 0.8280 - accuracy: 0.6942 - val_loss: 0.9723 - val_accuracy: 0.6429
#
# Epoch 00105: val_loss did not improve from 0.97043
# Epoch 106/110
# 898/897 [==============================] - 221s 246ms/step - loss: 0.8282 - accuracy: 0.6917 - val_loss: 0.9729 - val_accuracy: 0.6429
#
# Epoch 00106: val_loss did not improve from 0.97043
# Epoch 107/110
# 898/897 [==============================] - 328s 365ms/step - loss: 0.8355 - accuracy: 0.6916 - val_loss: 0.9724 - val_accuracy: 0.6427
#
# Epoch 00107: val_loss did not improve from 0.97043
# Epoch 108/110
# 898/897 [==============================] - 807s 899ms/step - loss: 0.8306 - accuracy: 0.6910 - val_loss: 0.9714 - val_accuracy: 0.6432
#
# Epoch 00108: val_loss did not improve from 0.97043
# Epoch 109/110
# 898/897 [==============================] - 354s 395ms/step - loss: 0.8373 - accuracy: 0.6888 - val_loss: 0.9724 - val_accuracy: 0.6429
#
# Epoch 00109: val_loss did not improve from 0.97043
# Epoch 110/110
# 898/897 [==============================] - 391s 435ms/step - loss: 0.8322 - accuracy: 0.6903 - val_loss: 0.9725 - val_accuracy: 0.6428
#
# Epoch 00110: val_loss did not improve from 0.97043

# %% [markdown]
# # Just for testing the model

# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import imutils
import cv2
import numpy as np
import sys
 
# parameters for loading data and images
detection_model_path = 'haarcascade_frontalface_default.xml'
emotion_model_path = 'models/_mini_XCEPTION.67.hdf5'
img_path = "images/angry.jpg" #sys.argv[1]
 
# hyper-parameters for bounding boxes shape
# loading models
face_detection = cv2.CascadeClassifier(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
EMOTIONS = ["angry","disgust","scared", "happy", "sad", "surprised","neutral"]
 
#reading the frame
orig_frame = cv2.imread(img_path)
frame = cv2.imread(img_path,0)
faces = face_detection.detectMultiScale(frame,scaleFactor=1.1,minNeighbors=5,minSize=(30,30),flags=cv2.CASCADE_SCALE_IMAGE)

if len(faces)>0:
    faces = sorted(faces, reverse=True,key=lambda x: (x[2] - x[0]) * (x[3] - x[1]))[0]
    (fX, fY, fW, fH) = faces
    roi = frame[fY:fY + fH, fX:fX + fW]
    roi = cv2.resize(roi, (48, 48))
    roi = roi.astype("float") / 255.0
    roi = img_to_array(roi)
    roi = np.expand_dims(roi, axis=0)
    preds = emotion_classifier.predict(roi)[0]
    emotion_probability = np.max(preds)
    label = EMOTIONS[preds.argmax()]
    cv2.putText(orig_frame, label, (fX, fY - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
    cv2.rectangle(orig_frame, (fX, fY), (fX + fW, fY + fH),(0, 0, 255), 2)
    
cv2.imshow('test_face', orig_frame)
cv2.imwrite('test_output/'+img_path.split('/')[-1],orig_frame)
if (cv2.waitKey(100000) & 0xFF == ord('q')):
    sys.exit("Thanks")
cv2.destroyAllWindows()
# Out:
# Using TensorFlow backend.
